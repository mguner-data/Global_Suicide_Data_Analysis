# %% [markdown]
# ### Importing dependencies

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
import csv
import numpy as np
import pandas as pd
import seaborn as sns
from scipy.optimize import curve_fit
import scipy
from scipy.stats import linregress

# %% [markdown]
# ### Reading the data

# %%
# Study data files
world_suicide_data_path_mg = "Suicide_Data_mg/master_mg.csv"
continent_path_mg = "Suicide_Data_mg/continents_mg.csv"

# Added another file for latitude
latitude_path_mg="Suicide_Data_mg/latitude.csv"

# Read the data and the study results
world_suicide_data_mg = pd.read_csv(world_suicide_data_path_mg)
continent_data_mg=pd.read_csv(continent_path_mg)
latitude_data=pd.read_csv(latitude_path_mg)

# %% [markdown]
#    ### Studying the raw data files

# %%
continent_data_mg.head()
# Out:
#          country      continent
# 0        Algeria         Africa
# 1         Angola         Africa
# 2          Aruba  South America
# 3          Benin         Africa
# 4  United States  North America

# %%
world_suicide_data_mg.head()
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop country-year  HDI for year gdp_for_year ($)   \
# 0               6.71  Albania1987           NaN     2,156,624,900
# 1               5.19  Albania1987           NaN     2,156,624,900
# 2               4.83  Albania1987           NaN     2,156,624,900
# 3               4.59  Albania1987           NaN     2,156,624,900
# 4               3.28  Albania1987           NaN     2,156,624,900
#
#    gdp_per_capita ($)       generation
# 0                 796     Generation X
# 1                 796           Silent
# 2                 796     Generation X
# 3                 796  G.I. Generation
# 4                 796          Boomers

# %%
# Fixed Republic of Korea in the continents and the titles then merge the two dataframes
world_suicide_df_mg2=world_suicide_data_mg.merge(continent_data_mg, on="country", how="left" )
world_suicide_df_mg2.columns
# Out:
# Index(['country', 'year', 'sex', 'age', 'suicides_no', 'population',
#        'suicides/100k pop', 'country-year', 'HDI for year',
#        'gdp_for_year ($) ', 'gdp_per_capita ($)', 'generation', 'continent'],
#       dtype='object')

# %%
# Bring continent column rigth after the index next to the country column
world_suicide_df_mg2=world_suicide_df_mg2[[ 'continent','country', 'year', 'sex', 'age', 'suicides_no', 'population',
       'suicides/100k pop', 'country-year', 'HDI for year',
       'gdp_for_year ($) ', 'gdp_per_capita ($)', 'generation']]
world_suicide_df_mg2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27820 entries, 0 to 27819
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   continent           27820 non-null  object
#  1   country             27820 non-null  object
#  2   year                27820 non-null  int64
#  3   sex                 27820 non-null  object
#  4   age                 27820 non-null  object
#  5   suicides_no         27820 non-null  int64
#  6   population          27820 non-null  int64
#  7   suicides/100k pop   27820 non-null  float64
#  8   country-year        27820 non-null  object
#  9   HDI for year        8364 non-null   float64
#  10  gdp_for_year ($)    27820 non-null  object
#  11  gdp_per_capita ($)  27820 non-null  int64
#  12  generation          27820 non-null  object
# dtypes: float64(2), int64(4), object(7)
# memory usage: 3.0+ MB

# %%
# Counting the number of data per to decide which years to filter
dseries_mg=world_suicide_df_mg2["year"].value_counts()
dseries_mg
# Out:
# 2009    1068
# 2001    1056
# 2010    1056
# 2007    1032
# 2011    1032
# 2002    1032
# 2003    1032
# 2000    1032
# 2006    1020
# 2008    1020
# 2005    1008
# 2004    1008
# 1999     996
# 2012     972
# 2013     960
# 1998     948
# 2014     936
# 1995     936
# 1996     924
# 1997     924
# 1994     816
# 1992     780
# 1993     780
# 1990     768
# 1991     768
# 2015     744
# 1987     648
# 1989     624
# 1988     588
# 1986     576
# 1985     576
# 2016     160
# Name: year, dtype: int64

# %%
# QA/QC for the number of countries vs. data counts
ds=world_suicide_df_mg2["country"].value_counts()
print(ds)
# Out:
# Mauritius                 382
# Iceland                   382
# Netherlands               382
# Austria                   382
# Chile                     372
#                          ...
# Bosnia and Herzegovina     24
# Macau                      12
# Dominica                   12
# Cabo Verde                 12
# Mongolia                   10
# Name: country, Length: 101, dtype: int64

# %%
# Main DataFrame Pre-Filtered merged with continents
world_suicide_df_mg2.head()
# Out:
#   continent  country  year     sex          age  suicides_no  population  \
# 0    Europe  Albania  1987    male  15-24 years           21      312900
# 1    Europe  Albania  1987    male  35-54 years           16      308000
# 2    Europe  Albania  1987  female  15-24 years           14      289700
# 3    Europe  Albania  1987    male    75+ years            1       21800
# 4    Europe  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop country-year  HDI for year gdp_for_year ($)   \
# 0               6.71  Albania1987           NaN     2,156,624,900
# 1               5.19  Albania1987           NaN     2,156,624,900
# 2               4.83  Albania1987           NaN     2,156,624,900
# 3               4.59  Albania1987           NaN     2,156,624,900
# 4               3.28  Albania1987           NaN     2,156,624,900
#
#    gdp_per_capita ($)       generation
# 0                 796     Generation X
# 1                 796           Silent
# 2                 796     Generation X
# 3                 796  G.I. Generation
# 4                 796          Boomers

# %%
#Write filtered data to new CSV
# Output File (CSV)

world_suicide_df_mg2.to_csv('Output_Data_mg/merged.csv', index=False)

# %%
# #Filtering the data from 2000 to 2014
world_suicide_df_2 = world_suicide_df_mg2.loc[(world_suicide_df_mg2["year"]>1999) & (world_suicide_df_mg2["year"]<=2014) ]

# %%
# Dropping the countries which do not have consistent data between 2000 to 2014 and writing it to csv in case needed
# Later on I will merge new_df2 with the main dataframe two further filter the entire dataframe

new_df=world_suicide_df_2.groupby(["country"]).size()
new_df2=new_df.reset_index(name='count')
new_df2=new_df2.loc[new_df2["count"]==180]
new_df2.info()
new_df2.to_csv('Output_Data_mg/new2.csv', index=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58 entries, 2 to 94
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   country  58 non-null     object
#  1   count    58 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.4+ KB

# %%
# New merge to create a brand new DataFrame for the new filtered DataFrame from 2000 to 2014
data_2000_2014=world_suicide_df_2.merge(new_df2, how="inner", on="country")
data_2000_2014.to_csv('Output_Data_mg/2000_2014.csv', index=False)
data_2000_2014.head()
# Out:
#        continent    country  year   sex          age  suicides_no  population  \
# 0  South America  Argentina  2000  male    75+ years          232      525161
# 1  South America  Argentina  2000  male  55-74 years          602     2333377
# 2  South America  Argentina  2000  male  35-54 years          578     4096814
# 3  South America  Argentina  2000  male  15-24 years          463     3306109
# 4  South America  Argentina  2000  male  25-34 years          331     2602314
#
#    suicides/100k pop   country-year  HDI for year gdp_for_year ($)   \
# 0              44.18  Argentina2000         0.762   284,203,750,000
# 1              25.80  Argentina2000         0.762   284,203,750,000
# 2              14.11  Argentina2000         0.762   284,203,750,000
# 3              14.00  Argentina2000         0.762   284,203,750,000
# 4              12.72  Argentina2000         0.762   284,203,750,000
#
#    gdp_per_capita ($)       generation  count
# 0                8462  G.I. Generation    180
# 1                8462           Silent    180
# 2                8462          Boomers    180
# 3                8462     Generation X    180
# 4                8462     Generation X    180

# %%
# Question 1 - Global Rate of Suicide increasing or Decreasing
global_15yrs=data_2000_2014.groupby("year").sum()
df_bar=global_15yrs.reset_index()
df_bar["suicide_rate"]=(df_bar["suicides_no"]/df_bar["population"])*100000
df_bar.plot(kind="bar",x="year", y="suicide_rate",rot=45, color="mediumslateblue")
plt.ylabel("Number of Suicides per 100K population")
plt.xlabel("Years")
plt.title("Number of Suicides per Years between 2000-2014")
plt.show()

# %%
# Top 5 countries for suicide rate of 2009
#merged2009_with_lat_df1.nlargest(10, 'suicide_normalized')

# # Top 5 countries for suicide rate of 2009
# merged2009_with_lat_df1.nlargest(10, 'suicide_normalized')

# %%
# Correlation Matrix

corr = df_bar.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# C:\Users\mguner\.conda\envs\PythonData\lib\site-packages\matplotlib\colors.py:527: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# C:\Users\mguner\.conda\envs\PythonData\lib\site-packages\pandas\io\formats\style.py:1089: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(s.to_numpy()) if vmin is None else vmin
# C:\Users\mguner\.conda\envs\PythonData\lib\site-packages\pandas\io\formats\style.py:1090: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(s.to_numpy()) if vmax is None else vmax
# <style  type="text/css" >
#     #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow0_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow0_col4 {
#             background-color:  #f7af91;
#             color:  #000000;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow0_col5 {
#             background-color:  #bd1f2d;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow0_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow0_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow1_col0 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow1_col2 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow1_col3 {
#             background-color:  #ca3b37;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow1_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow1_col5 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow1_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow1_col7 {
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow2_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow2_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow2_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow2_col4 {
#             background-color:  #f7b093;
#             color:  #000000;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow2_col5 {
#             background-color:  #bb1b2c;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow2_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow2_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow3_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow3_col1 {
#             background-color:  #cb3e38;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow3_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow3_col4 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow3_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow3_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow3_col7 {
#             background-color:  #b8122a;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow4_col0 {
#             background-color:  #f39475;
#             color:  #000000;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow4_col1 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow4_col2 {
#             background-color:  #f39577;
#             color:  #000000;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow4_col3 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow4_col5 {
#             background-color:  #f7ac8e;
#             color:  #000000;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow4_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow4_col7 {
#             background-color:  #84a7fc;
#             color:  #000000;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow5_col0 {
#             background-color:  #bd1f2d;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow5_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow5_col2 {
#             background-color:  #bb1b2c;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow5_col3 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow5_col4 {
#             background-color:  #f3c7b1;
#             color:  #000000;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow5_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow5_col7 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow6_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow6_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow6_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow6_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow6_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow6_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow6_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow6_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow7_col0 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow7_col1 {
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow7_col2 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_72bc1196_b42d_11ea_bd60_c8f75064a12erow7_col3 {
#             background-color:  #b8122a;
#             color:  #f1f1f1;

# %%
# Question 1-As line plot
df_bar.plot(kind="line",x="year", y="suicide_rate",rot=45, color="darkslategray")
plt.ylabel("Number of Suicides per 100K population")
plt.xlabel("Years")
plt.title("Number of Suicides per Years between 2000-2014")
x_n1=[2009,2009]
y_n1=[10,15]
plt.plot(x_n1, y_n1,linestyle="--",color="red")

plt.show()

# %%
# Question 1a) - Global Rate of Suicide per sex
gender_15yrs=data_2000_2014.groupby("sex").sum()
gender_15yrs2=gender_15yrs[["suicides_no"]]
gender_15yrs2=gender_15yrs2.rename(columns={"suicides_no": " "})
gender_15yrs2=gender_15yrs2.plot(kind="pie",subplots=True, autopct="%1.1f%%",startangle=120,colors = ['violet', 'cornflowerblue'])
plt.show()

# %%
# Question 1b) - Global Rate of Suicide per AgeGroup
age_15yrs=data_2000_2014.groupby("age").sum()
df_age=age_15yrs.reset_index()
# list1=[2,3,4,1,5,6]
# series=pd.Series(list1)
df_age2 = df_age.assign(list1=[2,3,4,1,5,6]) 
df_age2["normalized"]=df_age2["suicides_no"]/(df_age2["population"]/100000)
df_age3=df_age2.sort_values(by=["list1"])

df_age3.plot(kind="bar",x="age", y="normalized",rot=45, color="deepskyblue")
plt.ylabel("Number of Suicides per 100K population")
plt.xlabel("Age Groups")
plt.title("Number of Suicides per Age Groups between 2000-2014")
plt.show()

# %%
gender_15yrs
# Out:
#             year  suicides_no   population  suicides/100k pop  HDI for year  \
# sex
# female  10476540       712491  12022846328           29516.56      1848.054
# male    10476540      2440636  11448106398          113814.12      1848.054
#
#         gdp_per_capita ($)   count
# sex
# female           123343692  939600
# male             123343692  939600

# %%
# New DataFrame for the most countries for year 2009, because it has the most countries.

data_2009 = world_suicide_df_mg2.loc[(world_suicide_df_mg2["year"]==2009)] 
data_2009.to_csv('Output_Data_mg/2009.csv', index=False)
data_2009.head()
# Out:
#     continent  country  year     sex          age  suicides_no  population  \
# 240    Europe  Albania  2009  female  15-24 years            0      270003
# 241    Europe  Albania  2009  female  25-34 years            0      182712
# 242    Europe  Albania  2009  female  35-54 years            0      394286
# 243    Europe  Albania  2009  female   5-14 years            0      236174
# 244    Europe  Albania  2009  female  55-74 years            0      233302
#
#      suicides/100k pop country-year  HDI for year gdp_for_year ($)   \
# 240                0.0  Albania2009           NaN    12,044,212,904
# 241                0.0  Albania2009           NaN    12,044,212,904
# 242                0.0  Albania2009           NaN    12,044,212,904
# 243                0.0  Albania2009           NaN    12,044,212,904
# 244                0.0  Albania2009           NaN    12,044,212,904
#
#      gdp_per_capita ($)    generation
# 240                4387    Millenials
# 241                4387  Generation X
# 242                4387       Boomers
# 243                4387  Generation Z
# 244                4387        Silent

# %%
#Aggregate the total suicide_no per country for 2009 for quality check

data_2009_agg=data_2009.groupby("country").agg({"suicides_no":["sum"]})
data_2009_agg.columns = ['total_suicide_number']
data_2009_agg_by_num=data_2009_agg.reset_index()
data_2009_to_drop=data_2009_agg_by_num.loc[data_2009_agg_by_num["total_suicide_number"]==0]
data_2009_to_drop
# Out:
#                 country  total_suicide_number
# 0               Albania                     0
# 1   Antigua and Barbuda                     0
# 33              Grenada                     0

# %%
#Remove zero values, count number of countries =86 and continents = 6
data_2009_i=data_2009.set_index(['country'])
data_2009_clean=data_2009_i.loc[~data_2009_i.index.isin(['Albania','Antigua and Barbuda', 'Grenada'])]
data_2009_clean=data_2009_clean.reset_index()
data_2009_clean
# Out:
#          country      continent  year     sex          age  suicides_no  \
# 0      Argentina  South America  2009    male    75+ years          177
# 1      Argentina  South America  2009    male  15-24 years          609
# 2      Argentina  South America  2009    male  55-74 years          434
# 3      Argentina  South America  2009    male  25-34 years          504
# 4      Argentina  South America  2009    male  35-54 years          542
# ...          ...            ...   ...     ...          ...          ...
# 1027  Uzbekistan           Asia  2009  female    75+ years            7
# 1028  Uzbekistan           Asia  2009  female  35-54 years           65
# 1029  Uzbekistan           Asia  2009  female  55-74 years           15
# 1030  Uzbekistan           Asia  2009    male   5-14 years           37
# 1031  Uzbekistan           Asia  2009  female   5-14 years           18
#
#       population  suicides/100k pop    country-year  HDI for year  \
# 0         653486              27.09   Argentina2009           NaN
# 1        3436265              17.72   Argentina2009           NaN
# 2        2683502              16.17   Argentina2009           NaN
# 3        3210244              15.70   Argentina2009           NaN
# 4        4566645              11.87   Argentina2009           NaN
# ...          ...                ...             ...           ...
# 1027      318983               2.19  Uzbekistan2009           NaN
# 1028     3263931               1.99  Uzbekistan2009           NaN
# 1029     1105076               1.36  Uzbekistan2009           NaN
# 1030     2805898               1.32  Uzbekistan2009           NaN
# 1031     2678474               0.67  Uzbekistan2009           NaN
#
#      gdp_for_year ($)   gdp_per_capita ($)    generation
# 0      332,976,484,578                8961        Silent
# 1      332,976,484,578                8961    Millenials
# 2      332,976,484,578                8961        Silent
# 3      332,976,484,578                8961  Generation X
# 4      332,976,484,578                8961       Boomers
# ...                ...                 ...           ...
# 1027    33,689,223,673                1332        Silent
# 1028    33,689,223,673                1332       Boomers
# 1029    33,689,223,673                1332        Silent
# 1030    33,689,223,673                1332  Generation Z
# 1031    33,689,223,673                1332  Generation Z
#
# [1032 rows x 13 columns]

# %%
# Question 1a) - Global Rate of Suicide per sex for year 2009
gender_2009=data_2009_clean.groupby("sex").sum()
gender_2009_2=gender_2009[["suicides_no"]]
gender_2009_2=gender_2009_2.rename(columns={"suicides_no": " "})
gender_2009_2=gender_2009_2.plot(kind="pie",subplots=True, autopct="%1.1f%%",startangle=120)
plt.show()

# %%
gender_2009
# Out:
#            year  suicides_no  population  suicides/100k pop  HDI for year  \
# sex
# female  1036644        54920  1006509254            2418.08           0.0
# male    1036644       188567   966793226            9757.96           0.0
#
#         gdp_per_capita ($)
# sex
# female            11911452
# male              11911452

# %%
#Linear Regression

df_linear_2009=data_2009_clean.groupby("country").sum()
df_linear_2009=df_linear_2009.reset_index()
df_linear_2009["GDP per Capita"]=((df_linear_2009["gdp_per_capita ($)"]/12))
df_linear_2009["suicide_normalized"]=(df_linear_2009["suicides_no"]/df_linear_2009['population'])*100000

x_values = df_linear_2009['GDP per Capita']
y_values = df_linear_2009['suicide_normalized']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50000,25),fontsize=15, color="red")
plt.xlabel('GDP per Capita ($)')
plt.ylabel('Suicide Rate')
plt.title('Linear Regression for 2009 Data')
print(f"The r-squared is: {rvalue**2}")
print(line_eq)


plt.show()
# Out:
# The r-squared is: 0.0013388605890040572
# y = 0.0x + 11.17

# %%
#Linear Regression

df_linear_2009_1=data_2009_clean.groupby("country").sum()
df_linear_2009_1=df_linear_2009.reset_index()
df_linear_2009_1["GDP per Capita"]=((df_linear_2009_1["gdp_per_capita ($)"]/12))
df_linear_2009_1["suicide_normalized"]=(df_linear_2009_1["suicides_no"]/df_linear_2009_1['population'])*100000

x_values = df_linear_2009_1['population']
y_values = df_linear_2009_1['suicide_normalized']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50000,25),fontsize=15, color="red")
plt.xlabel('Population')
plt.ylabel('Suicide Rate')
plt.title('Linear Regression for 2009 Data')
print(f"The r-squared is: {rvalue**2}")
print(line_eq)


plt.show()
# Out:
# The r-squared is: 0.0029236077953354116
# y = 0.0x + 11.25

# %%
# Multiple Linear Regression
# Creating a line equation with two x values and a y value

df_linear_2009=data_2009_clean.groupby("country").sum()
df_linear_2009=df_linear_2009.reset_index()
df_linear_2009["GDP per Capita"]=((df_linear_2009["gdp_per_capita ($)"]/12))
df_linear_2009["suicide_normalized"]=(df_linear_2009["suicides_no"]/df_linear_2009['population'])*100000

df_linear_2009["GDP per Capita"].values #x1
df_linear_2009['population'].values #x2
df_linear_2009["suicide_normalized"].values #y

# Defining x and y into arrays to use in the function
new_x = np.concatenate(([df_linear_2009["GDP per Capita"].values],[df_linear_2009['population'].values]))
new_y = df_linear_2009["suicide_normalized"].values

# The function below returns Multiple Linear Regression Coefficients a, b and c

def fn(x, a, b, c):
    return a + b*x[0] + c*x[1] 

popt, pcov = curve_fit(fn, new_x, new_y)
print(popt)
# Out:
# [1.09541571e+01 1.32890529e-05 1.01645443e-08]

# %%
# %matplotlib inline

# This is to create a prediction from the line equation to compare the y values (sucide rate) and predicted_y values 
# to undersand if the correlation works fine or not
predicted_y = fn(new_x, 1.09541571e+01,1.32890529e-05,1.01645443e-08 )

pr_y=pd.Series(predicted_y)
n_y=pd.Series(new_y)

frame={"Real_y":n_y, "Predicted_y":pr_y}
df_plot=pd.DataFrame(frame)
df_plot.head()
scatter_plot = df_plot.plot(kind='scatter',x="Real_y", y="Predicted_y",color = 'teal',alpha=0.4, edgecolors="black",marker="o")
scatter_plot
x5=[0,35]
y5=[0,35]
plt.plot(x5,y5, linestyle="--", color="red")
plt.show()

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.scatter(np.array(new_x[0]),np.array( new_x[1]), np.array(new_y), alpha=0.5, color="violet",edgecolors="black")
plt.show()

# %%
# Finding out Lat. vs Suicide Rate 

merged2009_with_lat_df=data_2009_clean.merge(latitude_data, on="country", how="inner" )
merged2009_with_lat_df.head()
merged2009_with_lat_df.to_csv('Output_Data_mg/lat_2009_suicide.csv', index=False)
data_2009_clean.to_csv('Output_Data_mg/2009_suicide.csv', index=False)

# %%
merged2009_with_lat_df.head()
# Out:
#      country      continent  year   sex          age  suicides_no  population  \
# 0  Argentina  South America  2009  male    75+ years          177      653486
# 1  Argentina  South America  2009  male  15-24 years          609     3436265
# 2  Argentina  South America  2009  male  55-74 years          434     2683502
# 3  Argentina  South America  2009  male  25-34 years          504     3210244
# 4  Argentina  South America  2009  male  35-54 years          542     4566645
#
#    suicides/100k pop   country-year  HDI for year gdp_for_year ($)   \
# 0              27.09  Argentina2009           NaN   332,976,484,578
# 1              17.72  Argentina2009           NaN   332,976,484,578
# 2              16.17  Argentina2009           NaN   332,976,484,578
# 3              15.70  Argentina2009           NaN   332,976,484,578
# 4              11.87  Argentina2009           NaN   332,976,484,578
#
#    gdp_per_capita ($)    generation   latitude  longitude
# 0                8961        Silent -38.416097 -63.616672
# 1                8961    Millenials -38.416097 -63.616672
# 2                8961        Silent -38.416097 -63.616672
# 3                8961  Generation X -38.416097 -63.616672
# 4                8961       Boomers -38.416097 -63.616672

# %%
#Latitude Added to 2009

merged2009_with_lat_df1=merged2009_with_lat_df.groupby("country").sum()
merged2009_with_lat_df1=merged2009_with_lat_df1.reset_index()
merged2009_with_lat_df1["GDP per Capita"]=((merged2009_with_lat_df1["gdp_per_capita ($)"]/12))
merged2009_with_lat_df1["Latitude"]=((merged2009_with_lat_df1["latitude"]/12))
merged2009_with_lat_df1["suicide_normalized"]=(merged2009_with_lat_df1["suicides_no"]/merged2009_with_lat_df1['population'])*100000
merged2009_with_lat_df1.head()
# Out:
#      country   year  suicides_no  population  suicides/100k pop  HDI for year  \
# 0  Argentina  24108         2884    37158001             107.32           0.0
# 1    Armenia  24108           53     2689695              33.70           0.0
# 2      Aruba  24108            4       94795              42.23           0.0
# 3  Australia  24108         2337    20529317             130.12           0.0
# 4    Austria  24108         1278     7946894             213.22           0.0
#
#    gdp_per_capita ($)    latitude    longitude  GDP per Capita   Latitude  \
# 0              107532 -460.993164  -763.400064          8961.0 -38.416097
# 1               38580  480.829188   540.458268          3215.0  40.069099
# 2              316332  150.253320  -839.620056         26361.0  12.521110
# 3              541536 -303.292776  1605.301632         45128.0 -25.274398
# 4              604272  570.194772   174.600864         50356.0  47.516231
#
#    suicide_normalized
# 0            7.761451
# 1            1.970484
# 2            4.219632
# 3           11.383720
# 4           16.081755

# %%
# Top 5 countries for suicide rate of 2009
df_3=merged2009_with_lat_df1.nlargest(5, 'suicide_normalized')

df_3.plot(kind = "bar", x="country", y="suicide_normalized", color="lightgreen")
plt.xlabel(' ')
plt.ylabel('Suicide Rate')
plt.title("Top 5 Countries in Suicide Rate")
plt.show()

# %%
# Bottom 5 countries for suicide rate of 2009
merged2009_with_lat_df1.nsmallest(10, 'suicide_normalized')

# Top 5 countries for suicide rate of 2009
df_4=merged2009_with_lat_df1.nsmallest(5, 'suicide_normalized')

df_4.plot(kind = "bar", x="country", y="suicide_normalized", color="lightblue")
plt.xlabel(' ')
plt.ylabel('Suicide Rate')
plt.title("Bottom 5 Countries in Suicide Rate")
plt.show()

# %%
# Correlation Matrix

corr = merged2009_with_lat_df1.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# C:\Users\mguner\.conda\envs\PythonData\lib\site-packages\pandas\io\formats\style.py:1089: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(s.to_numpy()) if vmin is None else vmin
# C:\Users\mguner\.conda\envs\PythonData\lib\site-packages\pandas\io\formats\style.py:1090: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(s.to_numpy()) if vmax is None else vmax
# C:\Users\mguner\.conda\envs\PythonData\lib\site-packages\matplotlib\colors.py:527: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# <style  type="text/css" >
#     #T_73d28242_b42d_11ea_ba70_c8f75064a12erow0_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow0_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow0_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow0_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow0_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow0_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow0_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow1_col2 {
#             background-color:  #e8765c;
#             color:  #000000;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow1_col3 {
#             background-color:  #afcafc;
#             color:  #000000;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow1_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow1_col5 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow1_col6 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow1_col7 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow1_col8 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow1_col9 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow1_col10 {
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow2_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow2_col1 {
#             background-color:  #ec8165;
#             color:  #000000;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow2_col3 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow2_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow2_col5 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow2_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow2_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow2_col8 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow2_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow2_col10 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow3_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow3_col1 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow3_col2 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow3_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow3_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow3_col6 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow3_col7 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow3_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow3_col9 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow3_col10 {
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow4_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow4_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow4_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow4_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow4_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow4_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow4_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow4_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow4_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow4_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow4_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow5_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow5_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow5_col2 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow5_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73d28242_b42d_11ea_ba70_c8f75064a12erow5_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1

# %%
 
# Basic correlogram
sns.pairplot(merged2009_with_lat_df1)

# %%
x2=merged2009_with_lat_df1["Latitude"]
y2=merged2009_with_lat_df1["suicide_normalized"]


plt.scatter(x2,y2)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x2, y2)
regress_values = x2 * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x2,y2,color="teal")
plt.plot(x2,regress_values,"r-")
plt.annotate(line_eq,(0,20),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Suicide Rate')

print(f"The r-squared is: {rvalue**2}")
print(line_eq)

plt.show()
# Out:
# The r-squared is: 0.1345670337341077
# y = 0.11x + 8.29

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hem_df = merged2009_with_lat_df1.loc[(merged2009_with_lat_df1["Latitude"]>=0)]
southern_hem_df = merged2009_with_lat_df1.loc[(merged2009_with_lat_df1["Latitude"]<0)]

x_values = northern_hem_df['Latitude']
y_values = northern_hem_df["suicide_normalized"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,20),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Suicide Rate')

print(f"The r-squared is: {rvalue**2}")
print(line_eq)


plt.show()
# Out:
# The r-squared is: 0.2007332595779445
# y = 0.23x + 3.82

# %%
# Create Northern and Southern Hemisphere DataFrames
x_values = southern_hem_df['Latitude']
y_values = southern_hem_df["suicide_normalized"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-20,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Suicide Rate')

print(f"The r-squared is: {rvalue**2}")
print(line_eq)


plt.show()
# Out:
# The r-squared is: 0.22045248487712926
# y = -0.17x + 4.13
